# %% [markdown]
# ### Bài 1: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán phân loại domain câu bình luận trên bộ dữ liệu [UIT-ViOCD](https://drive.google.com/drive/folders/1Lu9axyLkw7dMx80uLRgvCnZsmNzhJWAa?usp=sharing).

# %% [markdown]
# ### Bài 2: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán gán nhãn chuỗi trên bộ dữ liệu [PhoNERT](https://github.com/VinAIResearch/PhoNER_COVID19).

# %%
import os
import sys
import json 

base_dir = os.getcwd()
data_dir = os.path.join(base_dir, 'dataset', 'UIT-Vi-OCD')

# Đọc train/dev/test small subset data
train_data = json.load(open(os.path.join(data_dir, 'train.json'), 'r', encoding='utf-8'))
dev_data = json.load(open(os.path.join(data_dir, 'dev.json'), 'r', encoding='utf-8'))
test_data = json.load(open(os.path.join(data_dir, 'test.json'), 'r', encoding='utf-8'))

# %%
def summarize_split(data, name):
    print(f"{name}: {len(data):,} mẫu")

summarize_split(train_data, "Train")
summarize_split(dev_data, "Dev")
summarize_split(test_data, "Test")

print("\nSample train:")
print(train_data["0"])
print(train_data["1"])
print(train_data["2"])
# Out:
# Train: 4,387 mẫu
# Dev: 548 mẫu
# Test: 549 mẫu
#
# Sample train:
# {'review': 'gói hàng cẩn thận . chơi pubg với liên quân mượt với giá như này thì quá tốt', 'label': 'non-complaint', 'domain': 'mobile'}
# {'review': 'mình góp ý thật nhé . . đừng bắt phải đăng nhập zalo nữa mình muốn tải nhạc mà không được lấy lại tôi không zalo thì gửi tin nhắn mất tiền được mã kích hoạt lại không chính xác . . mình thấy 10 ngưòi thì họ khó chịu cả 10 . . lập trình viên viết ra ứng dụng ngày càng dễ sử dụng đằng này càng ngày lại càng phức tạp và . . . bài đánh giá đầy đủ', 'label': 'complaint', 'domain': 'app'}
# {'review': 'máy khá đẹp , pin trâu vân tay nhạy nhận diện khuôn mặt nhanh nói chung ổn . tuy chơi game fre fire bị chậm khung hình không mượt lắm nhưng với giá giẫm ngày 1111 được ad mã giảm giá 200k còn hơn 2tr6 thì vậy là ngon rồi', 'label': 'complaint', 'domain': 'mobile'}

# %% [markdown]
# # 2. EDA

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Gộp dữ liệu từ các split để EDA tổng quan
def collect_texts(data_dict):
    return [v["review"] for v in data_dict.values()]

train_texts = collect_texts(train_data)
dev_texts   = collect_texts(dev_data)
test_texts  = collect_texts(test_data)

all_texts = train_texts + dev_texts + test_texts

print(f"Tổng số câu: {len(all_texts):,}")
# Out:
# Tổng số câu: 5,484

# %%
train_texts[:5]
# Out:
# ['gói hàng cẩn thận . chơi pubg với liên quân mượt với giá như này thì quá tốt',
#  'mình góp ý thật nhé . . đừng bắt phải đăng nhập zalo nữa mình muốn tải nhạc mà không được lấy lại tôi không zalo thì gửi tin nhắn mất tiền được mã kích hoạt lại không chính xác . . mình thấy 10 ngưòi thì họ khó chịu cả 10 . . lập trình viên viết ra ứng dụng ngày càng dễ sử dụng đằng này càng ngày lại càng phức tạp và . . . bài đánh giá đầy đủ',
#  'máy khá đẹp , pin trâu vân tay nhạy nhận diện khuôn mặt nhanh nói chung ổn . tuy chơi game fre fire bị chậm khung hình không mượt lắm nhưng với giá giẫm ngày 1111 được ad mã giảm giá 200k còn hơn 2tr6 thì vậy là ngon rồi',
#  'một mớ lỗi : không xem lại được bài test , không hiện link ( ví dụ như là youtube khi chia sẻ ) không copy được từ không biết để dịch . làm ơn cho về bản web đi',
#  'đặc mẫu xanh mà sao giao mẫu này vậy cửa hàng']

# %%
# Phân tích unique domains và keys trong train_data
print("=== Unique Domains trong Train Data ===")
unique_domains = set()
for item in train_data.values():
    unique_domains.add(item['domain'])

print(f"Số lượng unique domains: {len(unique_domains)}")
print(f"Các domains: {sorted(unique_domains)}")

print("\n=== Unique Keys trong Train Data ===")
# Lấy keys từ một mẫu đại diện
sample_keys = set(train_data["0"].keys())
print(f"Các keys có trong mỗi sample: {sorted(sample_keys)}")

print("\n=== Phân phối Domains ===")
domain_counts = {}
for item in train_data.values():
    domain = item['domain']
    domain_counts[domain] = domain_counts.get(domain, 0) + 1

for domain, count in sorted(domain_counts.items()):
    print(f"{domain}: {count:,} samples ({count/len(train_data)*100:.1f}%)")
    
print("\n=== Phân phối Labels ===")
label_counts = {}
for item in train_data.values():
    label = item['label']
    label_counts[label] = label_counts.get(label, 0) + 1

for label, count in sorted(label_counts.items()):
    print(f"{label}: {count:,} samples ({count/len(train_data)*100:.1f}%)")
# Out:
# === Unique Domains trong Train Data ===
# Số lượng unique domains: 4
# Các domains: ['app', 'cosmetic', 'fashion', 'mobile']
#
# === Unique Keys trong Train Data ===
# Các keys có trong mỗi sample: ['domain', 'label', 'review']
#
# === Phân phối Domains ===
# app: 1,613 samples (36.8%)
# cosmetic: 1,043 samples (23.8%)
# fashion: 1,368 samples (31.2%)
# mobile: 363 samples (8.3%)
#
# === Phân phối Labels ===
# complaint: 2,292 samples (52.2%)
# non-complaint: 2,095 samples (47.8%)

# %% [markdown]
# ## 2.1 Phân tích độ dài câu (token theo whitespace)

# %%
def sentence_length_whitespace(texts):
    lengths = [len(t.strip().split()) for t in texts]
    return np.array(lengths)

train_lens = sentence_length_whitespace(train_texts)
dev_lens   = sentence_length_whitespace(dev_texts)
test_lens  = sentence_length_whitespace(test_texts)

def summarize_lengths(lengths, name):
    print(f"{name}:")
    print(f"  Min: {lengths.min()}")
    print(f"  Mean: {lengths.mean():.2f}")
    print(f"  Median: {np.median(lengths)}")
    print(f"  Max: {lengths.max()}")
    print()

# %%
summarize_lengths(train_lens, "Train")
summarize_lengths(dev_lens, "Dev")
summarize_lengths(test_lens, "Test")
# Out:
# Train:
#   Min: 1
#   Mean: 31.65
#   Median: 20.0
#   Max: 256
#
# Dev:
#   Min: 1
#   Mean: 32.56
#   Median: 22.0
#   Max: 95
#
# Test:
#   Min: 1
#   Mean: 31.90
#   Median: 21.0
#   Max: 293

# %%
train_lens[:10]
# Out:
# array([18, 83, 50, 40, 11, 18,  6, 50,  7, 46])

# %% [markdown]
# Có thể thấy các giá trị thống kê cơ bản không có quá nhiều khác biệt, giá trị thống kê Max ở dev hơi nhỏ, tuy nhiên 1 số review quá dài có thể đang chạm ngưỡng rất ít, nên ta sẽ phân tích sâu trong phần max_len

# %% [markdown]
# ## 2.2 Phân tích phân phối độ dài để chọn `max_len`

# %% [markdown]
# Phần này không bắt buộc cho Transformer, nhưng hợp lý để lựa chọn max sequence length

# %%
def plot_length_distribution(lengths, title, percentiles=(90, 95, 99)):
    mean_len = lengths.mean()
    p99 = np.percentile(lengths, 99)

    plt.figure(figsize=(8, 4))
    plt.hist(lengths, bins=50)
    
    # Mean line
    plt.axvline(
        mean_len, 
        linestyle="--", 
        linewidth=2, 
        label=f"Mean = {mean_len:.1f}"
    )
    
    # 99th percentile line
    plt.axvline(
        p99, 
        linestyle="-", 
        linewidth=2, 
        label=f"99th percentile = {int(p99)}"
    )

    plt.title(title)
    plt.xlabel("Số token (whitespace)")
    plt.ylabel("Tần suất")
    plt.legend()
    plt.tight_layout()
    plt.show()

    for p in percentiles:
        print(f"{p}th percentile: {np.percentile(lengths, p):.0f}")

plot_length_distribution(train_lens, "Phân phối độ dài câu (Train)")
# Out:
# 90th percentile: 80
# 95th percentile: 84
# 99th percentile: 91

# %% [markdown]
# Phân phối độ dài câu lệch phải mạnh, có 1 số outliers cho câu dài nhưng trong ngữ cảnh review sản phẩm thì nó là điều bình thường

# %% [markdown]
# ## 2.3 Phân tích tập từ điển (min_freq – mang tính tham khảo)

# %% [markdown]
# Phần này chỉ dùng để mô tả dữ liệu, không dùng nếu dùng pretrained tokenizer

# %%
from collections import Counter

def build_vocab_whitespace(texts):
    counter = Counter()
    for t in texts:
        counter.update(t.strip().split())
    return counter

vocab_counter = build_vocab_whitespace(train_texts)

print(f"Tổng số token (train): {sum(vocab_counter.values()):,}")
print(f"Kích thước vocab (train): {len(vocab_counter):,}")
# Out:
# Tổng số token (train): 138,863
# Kích thước vocab (train): 4,629

# %%
vocab_counter
# Out:
# Counter({'.': 7089,
#          ',': 4057,
#          'không': 2780,
#          'hàng': 2271,
#          'được': 1823,
#          'có': 1801,
#          'rất': 1525,
#          'thì': 1307,
#          'mình': 1246,
#          'tôi': 1163,
#          'là': 1124,
#          'nhưng': 1104,
#          'lại': 1075,
#          'và': 1058,
#          'game': 954,
#          'cho': 944,
#          'mà': 940,
#          'giá': 915,
#          'giao': 881,
#          'một': 880,
#          'đẹp': 840,
#          'người': 811,
#          'này': 801,
#          'cửa': 779,
#          'chơi': 751,
#          'như': 699,
#          'đánh': 684,
#          'nên': 677,
#          'bài': 667,
#          'dụng': 656,
#          'nhiều': 646,
#          'khi': 644,
#          'đã': 638,
#          'mua': 633,
#          'sản': 633,
#          'tốt': 623,
#          'bị': 595,
#          'đủ': 588,
#          'cũng': 586,
#          'phẩm': 571,
#          'với': 569,
#          'để': 569,
#          'của': 567,
#          'mới': 564,
#          'quá': 548,
#          'đầy': 548,
#          'hay': 543,
#          'rồi': 532,
#          'sao': 527,
#          'thấy': 510,
#          'còn': 510,
#          'dùng': 509,
#          'hơn': 466,
#          'làm': 455,
#          'vào': 450,
#          'nhanh': 438,
#          'các': 438,
#          'màu': 438,
#          '!': 436,
#          'gì': 434,
#          'nhận': 428,
#          'trong': 428,
#          'bạn': 416,
#          'thể': 413,
#          'mong': 409,
#          'ra': 405,
#          'ứng': 401,
#          'phải': 400,
#          'hình': 399,
#          'lần': 398,
#          'sẽ': 391,
#          'từ': 385,
#          'chất': 384,
#          'nó': 372,
#          'chỉ': 369,
#          'vậy': 367,
#          'đặt': 358,
#          'cái': 356,
#          'lắm': 344,
#          'đi': 338,
#          'tài': 337,
#          'về': 334,
#          'những': 330,
#          'nữa': 325,
#          'vẫn': 324,
#          'thích': 321,
#          'luôn': 320,
#          'hơi': 319,
#          'đúng': 316,
#          'chưa': 308,
#          'ngày': 304,
#          'tiền': 301,
#          'vì': 301,
#          'lỗi': 298,
#          'cả': 296,
#          'cảm': 296,
#          'da': 292,
#          'lên': 292,
#          '2': 290,
#          '?': 285,
#          'lượng': 285,
#          'em': 279,
#          'quả': 278,
#          'nào': 278,
#          'đó': 275,
#          'sau': 270,
#          'biết': 268,
#          'phần': 267,
#          'đăng': 266,
#          'thêm': 266,
#          'nhật': 265,
#          'sử': 262,
#          'khoản': 261,
#          'tải': 258,
#          'lúc': 257,
#          'ạ': 253,
#          'đến': 249,
#          'tin': 247,
#          'học': 246,
#          'nói': 242,
#          'máy': 241,
#          'bảo': 240,
#          'khác': 240,
#          'điện': 239,
#          'cập': 232,
#          'ơn': 228,
#          'trên': 224,
#          'gói': 222,
#          'giờ': 222,
#          'vải': 221,
#          'vừa': 218,
#          'báo': 215,
#          'đóng': 214,
#          'bản': 213,
#          'hết': 213,
#          'mặt': 212,
#          'nếu': 212,
#          'tặng': 209,
#          'thoại': 209,
#          'nhà': 207,
#          ')': 203,
#          'anh': 203,
#          '(': 202,
#          'đầu': 202,
#          'mọi': 202,
#          'lòng': 199,
#          'đồ': 199,
#          'mất': 198,
#          'xem': 198,
#          'nhập': 195,
#          'cứ': 193,
#          'trước': 192,
#          'dễ': 191,
#          'thời': 189,
#          'khá': 188,
#          'mặc': 188,
#          'nha': 185,
#          'thế': 184,
#          'đang': 183,
#          'quần': 181,
#          'sự': 181,
#          'tiếng': 179,
#          'admin': 177,
#          'muốn': 174,
#          'tự': 174,
#          'gian': 171,
#          'hợp': 171,
#          'ý': 170,
#          'ap': 170,
#          'ở': 170,
#          'phát': 169,
#          'hài': 168,
#          'phục': 168,
#          'cáo': 168,
#          'trò': 168,
#          'thật': 167,
#          'hành': 167,
#          'chính': 166,
#          'số': 166,
#          'dù': 166,
#          'nhắn': 165,
#          'mấy': 165,
#          'lâu': 163,
#          'nhé': 162,
#          '3': 162,
#          'xài': 161,
#          'tính': 161,
#          'hộ': 160,
#          'càng': 158,
#          'cỡ': 157,
#          'cần': 153,
#          'tệ': 153,
#          '5star': 152,
#          'vô': 152,
#          ':': 148,
#          'hiện': 146,
#          'thông': 145,
#          'xong': 145,
#          'nhất': 144,
#          'ủng': 144,
#          'gửi': 142,
#          'tuyệt': 142,
#          'tại': 142,
#          'dịch': 141,
#          'giống': 141,
#          'khó': 140,
#          'qua': 140,
#          'hiệu': 139,
#          'mỗi': 139,
#          'thôi': 138,
#          'bình': 138,
#          'giúp': 137,
#          'liên': 136,
#          'đề': 136,
#          'ai': 136,
#          'chứ': 135,
#          'việt': 133,
#          '-': 133,
#          'năng': 132,
#          'vui': 131,
#          'đây': 129,
#          'tiếp': 129,
#          'son': 129,
#          'nghe': 129,
#          'do': 129,
#          'khách': 127,
#          'vọng': 126,
#          'đơn': 126,
#          'kết': 126,
#          'xuất': 126,
#          'thường': 124,
#          'đổi': 124,
#          'cách': 124,
#          'yêu': 123,
#          'thành': 122,
#          'ok': 121,
#          'đâu': 121,
#          'nay': 121,
#          'thử': 120,
#          'tình': 120,
#          'ảnh': 119,
#          'theo': 118,
#          'áo': 118,
#          'đều': 117,
#          'ăn': 117,
#          'lazada': 116,
#          'nhân': 116,
#          'mụn': 115,
#          'xoá': 115,
#          'bán': 115,
#          'hãng': 115,
#          'dung': 114,
#          'bắt': 113,
#          'khắc': 113,
#          'quà': 113,
#          'ổn': 112,
#          'mẫu': 111,
#          'bao': 111,
#          'trả': 110,
#          'điều': 110,
#          'trang': 110,
#          'mở': 109,
#          'động': 109,
#          'nạp': 109,
#          'thận': 108,
#          'chắc': 108,
#          'sai': 108,
#          'chọn': 108,
#          'cẩn': 107,
#          'xác': 107,
#          'chịu': 106,
#          'thất': 106,
#          'tạo': 106,
#          'thứ': 105,
#          'kem': 105,
#          'việc': 105,
#          'cực': 105,
#          'hoạt': 104,
#          'gọi': 104,
#          'cùng': 104,
#          'kích': 103,
#          'rẻ': 103,
#          'công': 101,
#          'hôm': 100,
#          'độ': 100,
#          'nhiên': 100,
#          'kèm': 99,
#          'tra': 99,
#          'xin': 99,
#          'gần': 97,
#          'facebok': 95,
#          'viên': 94,
#          'giảm': 94,
#          'cài': 94,
#          'bằng': 94,
#          'chuyển': 93,
#          'nhìn': 93,
#          'vời': 93,
#          'nhỏ': 93,
#          'sửa': 93,
#          'sáng': 92,
#          'hiểu': 92,
#          'tâm': 92,
#          'nguyên': 91,
#          'ít': 91,
#          'vấn': 91,
#          'bộ': 91,
#          'con': 90,
#          'chung': 89,
#          'mỏng': 88,
#          'điểm': 88,
#          'mã': 87,
#          'toàn': 87,
#          'bên': 87,
#          'lý': 87,
#          'mịn': 86,
#          'cao': 86,
#          'phiên': 86,
#          '😍': 86,
#          'chữ': 86,
#          'hoặc': 85,
#          'mùi': 85,
#          'tới': 84,
#          'kiểu': 84,
#          'tìm': 84,
#          'hỏi': 83,
#          'dép': 83,
#          'dài': 82,
#          'kiểm': 82,
#          'rửa': 82,
#          'đồng': 80,
#          'chế': 80,
#          'y': 80,
#          'cũ': 79,
#          'hãy': 79,
#          'mềm': 78,
#          'giải': 77,
#          'vị': 77,
#          'mãi': 75,
#          'đáng': 75,
#          'lấy': 74,
#          'thiện': 74,
#          'chán': 74,
#          'chút': 74,
#          'vài': 74,
#          'nghĩ': 74,
#          'tay': 73,
#          '👍': 73,
#          'tục': 73,
#          'huỷ': 73,
#          'tuy': 72,
#          '1star': 72,
#          'ngoài': 72,
#          'mật': 71,
#          'màn': 71,
#          'hạn': 71,
#          'trắng': 71,
#          'âm': 71,
#          'đừng': 70,
#          'hộp': 70,
#          'vụ': 70,
#          'star': 70,
#          'đợi': 69,
#          'xét': 69,
#          'tiện': 69,
#          'ưng': 68,
#          'rõ': 68,
#          'xe': 68,
#          'ta': 67,
#          'nạ': 67,
#          'ích': 67,
#          'quốc': 67,
#          'đọc': 67,
#          'cấp': 66,
#          'chờ': 66,
#          'mang': 66,
#          'minh': 66,
#          'lag': 65,
#          'ơi': 65,
#          'nghĩa': 65,
#          'nhạc': 64,
#          'tuần': 64,
#          'hồi': 63,
#          'cám': 63,
#          'nhau': 63,
#          'hang': 63,
#          'xế': 63,
#          'chỉnh': 63,
#          'chậm': 62,
#          'khuyến': 62,
#          'dầu': 62,
#          'chuẩn': 62,
#          'định': 62,
#          'quan': 62,
#          'mượt': 61,
#          'loại': 61,
#          'positive': 61,
#          'mạng': 61,
#          '5': 61,
#          'lời': 61,
#          'trình': 60,
#          'liệu': 60,
#          '😡': 60,
#          '4': 60,
#          'sinh': 60,
#          'uy': 60,
#          'sữa': 60,
#          '❤': 60,
#          'xanh': 59,
#          'thiếu': 59,
#          'bây': 59,
#          'hoàn': 59,
#          'tháng': 59,
#          'bỏ': 59,
#          'thiết': 59,
#          'nhẹ': 59,
#          'triển': 58,
#          'cầu': 58,
#          'vật': 58,
#          'thương': 58,
#          'khẩu': 57,
#          'khoá': 57,
#          'hoá': 57,
#          'đầm': 57,
#          'nhớ': 57,
#          'facebook': 57,
#          'rộng': 56,
#          'cải': 56,
#          'phù': 56,
#          'chức': 56,
#          'trừ': 56,
#          'tín': 56,
#          'danh': 56,
#          'may': 56,
#          'nền': 55,
#          'lớn': 55,
#          'thi': 55,
#          'phí': 55,
#          'viết': 54,
#          'ghi': 54,
#          'chủ': 54,
#          'hồng': 54,
#          'sớm': 54,
#          'năm': 53,
#          'tất': 53,
#          'i': 53,
#          'video': 53,
#          'bấm': 53,
#          'chẳng': 53,
#          'nghiệm': 53,
#          'chai': 52,
#          'thân': 52,
#          'thoát': 52,
#          'tạm': 52,
#          'ngay': 52,
#          'môi': 52,
#          'nam': 51,
#          'chạy': 51,
#          'chỗ': 51,
#          'nổi': 51,
#          'lưu': 51,
#          'lừa': 51,
#          'câu': 51,
#          'chúng': 50,
#          'kì': 50,
#          'tối': 50,
#          'bất': 50,
#          'ngắn': 49,
#          'thực': 49,
#          'trợ': 49,
#          'kiện': 48,
#          'biệt': 48,
#          'chắn': 47,
#          'seal': 47,
#          'thanh': 47,
#          'tắt': 47,
#          'nhiệt': 47,
#          'đặc': 46,
#          'đỏ': 46,
#          'khô': 46,
#          'từng': 46,
#          'trời': 46,
#          'shiper': 46,
#          'tưởng': 46,
#          'xấu': 46,
#          'đường': 46,
#          'đen': 46,
#          'thay': 45,
#          'hai': 45,
#          'siêu': 45,
#          'đôi': 45,
#          'vựng': 45,
#          'hệ': 44,
#          'nghị': 44,
#          'trí': 44,
#          'chân': 44,
#          'giác': 44,
#          'hữu': 44,
#          'tác': 44,
#          'mẹ': 44,
#          'zalo': 43,
#          'rat': 43,
#          'hoạ': 43,
#          'lồn': 43,
#          'khoảng': 43,
#          'vãi': 43,
#          'kiến': 43,
#          '1': 43,
#          'diện': 42,
#          'chả': 42,
#          'wifi': 42,
#          'hề': 42,
#          'gia': 42,
#          'tư': 42,
#          'mau': 42,
#          'lập': 41,
#          'chống': 41,
#          'xuống': 41,
#          'chị': 41,
#          'quay': 41,
#          'đối': 41,
#          'chuyện': 41,
#          'kiếm': 41,
#          'tập': 41,
#          'thu': 40,
#          'thú': 40,
#          'tướng': 40,
#          'tốn': 40,
#          'toi': 40,
#          'hát': 40,
#          'trải': 40,
#          'nhờ': 40,
#          'tổng': 40,
#          'họ': 39,
#          'đứng': 39,
#          'nước': 39,
#          'c': 39,
#          'đấy': 39,
#          'bật': 39,
#          'vip': 39,
#          'dẫn': 39,
#          'khiến': 39,
#          'kĩ': 39,
#          'hỗ': 39,
#          '10': 38,
#          'pin': 38,
#          'ấy': 38,
#          '%': 38,
#          'buồn': 38,
#          'co': 38,
#          'phản': 38,
#          'kí': 38,
#          'thâm': 38,
#          'trung': 38,
#          'bé': 38,
#          'trở': 37,
#          'sức': 37,
#          'hút': 37,
#          '👎': 37,
#          'tí': 37,
#          'sách': 37,
#          'hack': 36,
#          'tẩy': 36,
#          'tầm': 36,
#          'xíu': 36,
#          'xử': 36,
#          'yên': 36,
#          'bực': 36,
#          'nhiêu': 36,
#          'hướng': 36,
#          'e': 36,
#          'nối': 35,
#          'thơm': 35,
#          'dòng': 35,
#          'luận': 35,
#          'thẻ': 35,
#          'trạng': 34,
#          'vận': 34,
#          'mạnh': 34,
#          'bổ': 34,
#          'phút': 34,
#          'tả': 34,
#          'chuyến': 34,
#          'đỡ': 34,
#          'đảo': 34,
#          'giới': 34,
#          'đài': 34,
#          'luyện': 34,
#          'góp': 33,
#          'ban': 33,
#          'xúc': 33,
#          'gặp': 33,
#          'thủ': 33,
#          'sale': 33,
#          'mắt': 33,
#          'á': 33,
#          'tượng': 33,
#          'ngữ': 33,
#          'tiên': 32,
#          'tiki': 32,
#          'kia': 32,
#          'mục': 32,
#          'cuối': 32,
#          'sang': 32,
#          'thống': 32,
#          'túi': 32,
#          'kỳ': 32,
#          'ngon': 31,
#          'tinh': 31,
#          'vệ': 31,
#          'nặng': 31,
#          'kêu': 31,
#          'vi': 31,
#          'tăng': 31,
#          'hẹn': 31,
#          'to': 31,
#          'bè': 31,
#          'trọng': 31,
#          'lí': 31,
#          'mái': 31,
#          'tên': 31,
#          'vàng': 31,
#          'ad': 30,
#          'cố': 30,
#          'đội': 30,
#          'nâng': 30,
#          'à': 30,
#          'kém': 30,
#          'đấu': 30,
#          'ma': 30,
#          'tik': 30,
#          'tok': 30,
#          'lạc': 30,
#          'thị': 30,
#          'chấp': 30,
#          'thức': 30,
#          'thoải': 30,
#          'xu': 30,
#          'vẻ': 30,
#          'sạch': 30,
#          'chương': 30,
#          'gây': 29,
#          'quyết': 29,
#          'chiến': 29,
#          'lớp': 29,
#          'rách': 29,
#          'tương': 29,
#          'khuyên': 29,
#          'ký': 29,
#          'thấm': 28,
#          'khỏi': 28,
#          'lợi': 28,
#          'nhung': 28,
#          'grab': 28,
#          'riêng': 28,
#          'chi': 28,
#          'ràng': 28,
#          'cày': 28,
#          'mesenger': 28,
#          'trị': 28,
#          'test': 27,
#          'bớt': 27,
#          'món': 27,
#          'cộng': 27,
#          'cân': 27,
#          'toán': 27,
#          'nút': 27,
#          'tai': 27,
#          'nội': 27,
#          'cung': 27,
#          'êm': 27,
#          'hoài': 27,
#          'dưới': 27,
#          '😂': 27,
#          'cam': 27,
#          'kỹ': 27,
#          'ví': 26,
#          '😘': 26,
#          'đưa': 26,
#          'nhiệm': 26,
#          'ac': 26,
#          'tiêu': 26,
#          'máu': 26,
#          'kinh': 26,
#          'nhấn': 26,
#          'dân': 26,
#          'tem': 26,
#          'mô': 26,
#          'nắng': 26,
#          'trường': 26,
#          'sever': 26,
#          'hẳn': 26,
#          'lạ': 26,
#          'dạng': 26,
#          'tuổi': 25,
#          'ko': 25,
#          'cá': 25,
#          'nhu': 25,
#          '9': 25,
#          'dàng': 25,
#          'mát': 25,
#          'tế': 25,
#          'ức': 25,
#          'dành': 25,
#          'kan': 25,
#          'gogle': 25,
#          'xuyên': 24,
#          'giữa': 24,
#          'giật': 24,
#          'trận': 24,
#          'tức': 24,
#          'địa': 24,
#          'tuýp': 24,
#          'dạo': 24,
#          'trì': 24,
#          'fix': 24,
#          'ung': 23,
#          'nè': 23,
#          'ấn': 23,
#          'dữ': 23,
#          'chật': 23,
#          'nhầm': 23,
#          'k': 23,
#          'dày': 23,
#          'nen': 23,
#          'đơ': 23,
#          'kể': 23,
#          'tận': 23,
#          'bóng': 23,
#          'quyền': 23,
#          'phạm': 23,
#          'twiter': 23,
#          'vai': 23,
#          'đa': 23,
#          'dụ': 22,
#          'lọ': 22,
#          'load': 22,
#          'nắp': 22,
#          'vòng': 22,
#          'phiền': 22,
#          'chiều': 22,
#          'rằng': 22,
#          'tiết': 22,
#          'tốc': 22,
#          'cuộc': 22,
#          'hiển': 22,
#          'nóng': 22,
#          'pokemon': 22,
#          'sắc': 22,
#          'vng': 22,
#          'zing': 22,
#          'dùm': 22,
#          'online': 22,
#          'thua': 22,
#          'nhỉ': 22,
#          '+': 22,
#          'bệnh': 22,
#          'bang': 22,
#          '😚': 22,
#          'v': 22,
#          'sẻ': 21,
#          'moi': 21,
#          'nhắc': 21,
#          'đáp': 21,
#          'tuỳ': 21,
#          'sợ': 21,
#          'mini': 21,
#          'kế': 21,
#          'ngờ': 21,
#          'dưỡng': 21,
#          'chuyên': 21,
#          'bọt': 21,
#          'samsung': 21,
#          'hi': 21,
#          'mờ': 21,
#          'văn': 21,
#          'out': 21,
#          'lịch': 21,
#          'fre': 20,
#          'chia': 20,
#          'nơi': 20,
#          'vết': 20,
#          'chú': 20,
#          'giả': 20,
#          'bảng': 20,
#          'phong': 20,
#          'cấu': 20,
#          'm': 20,
#          'chết': 20,
#          'tiếc': 20,
#          'la': 20,
#          'email': 20,
#          'gàu': 20,
#          'ngồi': 20,
#          'r': 20,
#          't': 20,
#          'trẻ': 20,
#          'thưởng': 20,
#          'cục': 20,
#          'cây': 20,
#          'dính': 20,
#          'căng': 20,
#          'tông': 20,
#          'nửa': 20,
#          '😠': 20,
#          'tội': 19,
#          'lo': 19,
#          'nhờn': 19,
#          'tố': 19,
#          'va': 19,
#          'tử': 19,
#          'phụ': 19,
#          'lai': 19,
#          'cơ': 19,
#          'xảy': 19,
#          'chửi': 19,
#          'xa': 19,
#          'nhóm': 19,
#          'lực': 19,
#          '😊': 19,
#          'rít': 19,
#          '😭': 19,
#          'hội': 19,
#          'quân': 18,
#          'quên': 18,
#          'đòi': 18,
#          'chăm': 18,
#          'coi': 18,
#          'di': 18,
#          'sài': 18,
#          'văng': 18,
#          'hưởng': 18,
#          '100': 18,
#          '6': 18,
#          'liền': 18,
#          'bàn': 18,
#          'sạc': 18,
#          'play': 18,
#          'yếu': 18,
#          'ẩm': 18,
#          'truyện': 18,
#          'long': 18,
#          'nph': 18,
#          'hinh': 18,
#          'miễn': 18,
#          'lựa': 18,
#          'đất': 18,
#          '🥰': 18,
#          'thái': 17,
#          'chí': 17,
#          '50': 17,
#          'gym': 17,
#          'sơ': 17,
#          '👌': 17,
#          'chúc': 17,
#          'nho': 17,
#          'mức': 17,
#          '20': 17,
#          'form': 17,
#          'chóng': 17,
#          'ghê': 17,
#          'móp': 17,
#          '7': 17,
#          'ghét': 17,
#          'đoạn': 17,
#          'đợt': 17,
#          'chê': 17,
#          'thư': 17,
#          'pháp': 17,
#          'hại': 17,
#          'san': 17,
#          'phấn': 17,
#          'trâu': 16,
#          'lệ': 16,
#          'bắn': 16,
#          'suốt': 16,
#          'the': 16,
#          'duoc': 16,
#          'check': 16,
#          'dấu': 16,
#          'phép': 16,
#          'giản': 16,
#          'thiệt': 16,
#          'duy': 16,
#          'in': 16,
#          '😁': 16,
#          's': 16,
#          'chục': 16,
#          'cầm': 16,
#          'trôi': 16,
#          'che': 16,
#          'đem': 16,
#          'lưng': 16,
#          'cảnh': 16,
#          'tươi': 16,
#          'nhan': 16,
#          'ngôn': 16,
#          'gmail': 16,
#          'gỡ': 16,
#          'bởi': 16,
#          '0': 16,
#          'nhãn_hiệu': 15,
#          'sát': 15,
#          'xếp': 15,
#          'nản': 15,
#          'mắc': 15,
#          'ofline': 15,
#          'trễ': 15,
#          'choi': 15,
#          'lỗ': 15,
#          'se': 15,
#          'nv': 15,
#          'voi': 15,
#          'sắp': 15,
#          'line': 15,
#          'mail': 15,
#          'god': 15,
#          'lẽ': 15,
#          'cuốc': 15,
#          'mùa': 15,
#          'ful': 15,
#          'ông': 15,
#          'phá': 15,
#          'skin': 15,
#          'lặp': 15,
#          'đành': 15,
#          'bôi': 15,
#          'code': 15,
#          'chụp': 15,
#          'kéo': 15,
#          'giáo': 15,
#          'khung': 14,
#          'hạng': 14,
#          'thấp': 14,
#          'dẹp': 14,
#          'sóc': 14,
#          'súng': 14,
#          'o': 14,
#          'lót': 14,
#          'tranh': 14,
#          'be': 14,
#          'đại': 14,
#          'xinh': 14,
#          'khoẻ': 14,
#          'khôi': 14,
#          'ẩn': 14,
#          'mệt': 14,
#          'phố': 14,
#          'hoi': 14,
#          'nữ': 14,
#          'voan': 14,
#          'nhiễm': 14,
#          'vua': 14,
#          'dừng': 14,
#          'bo': 14,
#          'phủ': 14,
#          'kiềm': 14,
#          'instagram': 14,
#          'điển': 14,
#          'vùng': 14,
#          'chó': 14,
#          'mal': 14,
#          'dáng': 14,
#          'garena': 14,
#          'phim': 14,
#          'đắt': 14,
#          'file': 14,
#          'chào': 13,
#          'thậm': 13,
#          'giấy': 13,
#          'lông': 13,
#          'goi': 13,
#          'hy': 13,
#          'sticker': 13,
#          'gấp': 13,
#          'tựa': 13,
#          'cai': 13,
#          'server': 13,
#          'world': 13,
#          'dây': 13,
#          'thich': 13,
#          'ho': 13,
#          'xịn': 13,
#          'váy': 13,
#          'mại': 13,
#          'án': 13,
#          'truy': 13,
#          'hấp': 13,
#          'thèm': 13,
#          'thiệu': 13,
#          'giữ': 13,
#          'buộc': 13,
#          'bong': 13,
#          'monkey': 13,
#          'mai': 13,
#          'bọn': 13,
#          'áp': 13,
#          '37': 13,
#          '38': 13,
#          'ba': 13,
#          ...})

# %%
def analyze_min_freq(counter, freqs=(1, 2, 5, 10)):
    for f in freqs:
        kept = sum(1 for _, c in counter.items() if c >= f)
        print(f"min_freq ≥ {f}: vocab size = {kept:,}")

analyze_min_freq(vocab_counter)
# Out:
# min_freq ≥ 1: vocab size = 4,629
# min_freq ≥ 2: vocab size = 2,757
# min_freq ≥ 5: vocab size = 1,692
# min_freq ≥ 10: vocab size = 1,191

# %% [markdown]
# Rất nhiều token xuất hiện 1–2 lần
#
# => Phản ánh: Lỗi chính tả, các biến thể (không dấu), icon,...
#
# => Việc cắt vocab theo min_freq không phù hợp với dữ liệu nhiễu

# %% [markdown]
# # 3. Kết luận
# - Tập dữ liệu UIT-ViOCD gồm 5,484 câu bình luận, với độ dài câu phân bố tương đối đồng đều giữa các tập Train, Dev và Test.
# - Độ dài câu trung bình dao động quanh 32 token, trong khi median chỉ khoảng 20–22 token, cho thấy phân phối lệch phải với một số câu rất dài.
# - Phần lớn câu có độ dài vừa phải: 90% câu ≤ 80 token, 95% ≤ 84 token và 99% ≤ 91 token, tuy vẫn tồn tại một số ngoại lệ có độ dài trên 250 token.
# - Tập từ vựng huấn luyện có 4,629 token, trong đó tỷ lệ lớn là các token tần suất thấp; khi tăng ngưỡng min_freq, kích thước vocab giảm nhanh.
# - Các đặc điểm trên phản ánh dữ liệu có mức độ nhiễu cao (lỗi chính tả, biến thể từ, câu ngắn và dài xen kẽ), qua đó ủng hộ việc sử dụng tokenizer pretrained và lựa chọn độ dài chuỗi đầu vào cố định (ví dụ 128) để đảm bảo hiệu quả và ổn định khi huấn luyện Transformer Encoder.
